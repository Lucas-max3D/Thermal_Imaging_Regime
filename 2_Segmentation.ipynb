# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

def load_frame_metrics(filename="frame_metrics.pkl"):
    """
    Load the nested dictionary containing multiple metrics per video from a pickle file.
    Structure: {cube -> {condition -> {line -> {metric -> 1D array}}}}
    """
    with open(filename, "rb") as f:
        data = pickle.load(f)
    print(f"Loaded frame metrics from {filename}")
    return data

def plot_metric(results, cube, condition, line, metric_name, window_size=50):
    """
    Plot evolution of a chosen metric showing both raw and filtered signals.
    The raw signal is colored based on thresholds calculated from filtered data.
    
    Parameters
    ----------
    results : dict
        Pre-computed results dictionary
    cube : int
        Cube number
    condition : int
        Condition number
    line : int
        Line number
    metric_name : str
        Name of the metric to plot ('intensities', 'saturated_pixels', or 'max_values')
    window_size : int
        Size of the moving average window for filtering
    """
    signal = results[cube][condition][line][metric_name]
    frames = range(len(signal))
    
    # Filter signal for threshold calculation (centered moving average)
    filtered_signal = np.convolve(signal, np.ones(window_size)/window_size, mode='same')
    
    # Calculate threshold using filtered signal
    p90 = np.percentile(filtered_signal, 99)
    p10 = np.percentile(filtered_signal, 1)
    th = (p90-p10) * 0.3 + p10
    
    print(f"99th percentile: {p90:.2f}")
    print(f"1st percentile: {p10:.2f}")
    print(f"Calculated threshold: {th:.2f}")
    
    ylabel_map = {
        'intensities': 'Sum of pixel intensities',
        'saturated_pixels': 'Number of saturated pixels',
        'max_values': 'Maximum pixel value'
    }
    
    plt.figure(figsize=(6,4))
    
    # Plot raw signal values based on filtered threshold
    mask_below = [x <= th for x in signal]
    plt.plot(frames, [s if m else None for s, m in zip(signal, mask_below)], 
             color='blue', label='Normal')
    
    mask_above = [x > th for x in signal]
    plt.plot(frames, [s if m else None for s, m in zip(signal, mask_above)], 
             color='red', label='Above threshold')
    
    # Plot filtered signal
    plt.plot(frames, filtered_signal, color='green', alpha=0.5, 
             linestyle='--', label='Filtered signal')
    
    plt.axhline(y=th, color='gray', linestyle='--', 
                label=f'Threshold (filtered signal)')
    plt.xlabel('Frame index')
    plt.ylabel(ylabel_map[metric_name])
    plt.title(f'Evolution of {metric_name.replace("_", " ")} over time')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_all_metrics(results, cube, condition, line):
    """
    Create a figure with subplots showing all metrics for a specific video.
    
    Parameters
    ----------
    results : dict
        The nested dictionary containing the metrics
    cube : int
        Cube number
    condition : int
        Condition number
    line : int
        Line number
    """
    metrics = ['intensities', 'saturated_pixels', 'max_values']
    
    fig, axes = plt.subplots(3, 1, figsize=(8, 10))
    fig.suptitle(f'Metrics Evolution: Cube={cube}, Condition={condition}, Line={line}')
    
    ylabel_map = {
        'intensities': 'Sum of pixel intensities',
        'saturated_pixels': 'Number of saturated pixels',
        'max_values': 'Maximum pixel value'
    }
    
    for ax, metric in zip(axes, metrics):
        signal = results[cube][condition][line][metric]
        ax.plot(signal)
        ax.set_xlabel('Frame index')
        ax.set_ylabel(ylabel_map[metric])
        ax.grid(True)
    
    plt.tight_layout()
    plt.show()

def plot_metric_comparison(results, cube, condition, metrics_to_compare=None):
    """
    Plot the same metric for all lines in a given condition, allowing for comparison.
    
    Parameters
    ----------
    results : dict
        The nested dictionary containing the metrics
    cube : int
        Cube number
    condition : int
        Condition number
    metrics_to_compare : list of str, optional
        List of metrics to compare. If None, plots all metrics.
    """
    if metrics_to_compare is None:
        metrics_to_compare = ['intensities', 'saturated_pixels', 'max_values']
    
    ylabel_map = {
        'intensities': 'Sum of pixel intensities',
        'saturated_pixels': 'Number of saturated pixels',
        'max_values': 'Maximum pixel value'
    }
    
    n_metrics = len(metrics_to_compare)
    fig, axes = plt.subplots(n_metrics, 1, figsize=(10, 4*n_metrics))
    if n_metrics == 1:
        axes = [axes]
    
    fig.suptitle(f'Metrics Comparison: Cube={cube}, Condition={condition}')
    
    for ax, metric in zip(axes, metrics_to_compare):
        for line in results[cube][condition].keys():
            signal = results[cube][condition][line][metric]
            ax.plot(signal, label=f'Line {line}')
        
        ax.set_xlabel('Frame index')
        ax.set_ylabel(ylabel_map[metric])
        ax.legend()
        ax.grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
results = load_frame_metrics("frame_metrics.pkl")
# Out:
# Loaded frame metrics from frame_metrics.pkl

# %%
plot_metric(results, cube=1, condition=1, line=1, metric_name='max_values')

# %%
plot_metric(results, cube=2, condition=2, line=2, metric_name='max_values')

# %%
plot_metric(results, cube=3, condition=3, line=3, metric_name='max_values')

# %%
plot_metric(results, cube=4, condition=4, line=4, metric_name='max_values')

# %%
# Loop through all cubes, conditions, and lines
for cube in range(1, 5):         # Cubes: 1 to 4
    for condition in range(1, 13):  # Conditions: 1 to 12
        for line in range(1, 6):     # Lines: 1 to 5
            # Check if the data exists before plotting
            if (cube in results and 
                condition in results[cube] and 
                line in results[cube][condition]):
                
                print(f"Plotting: Cube={cube}, Condition={condition}, Line={line}")
                plot_metric(results, cube=cube, condition=condition, line=line, metric_name='max_values')
            else:
                print(f"Skipping: Cube={cube}, Condition={condition}, Line={line} (No Data Found)")

# %%
import os
import numpy as np
import tifffile
import pickle
import shutil
from pathlib import Path

def find_segmentation_range(signal, threshold_ratio=0.3, window_size=50):
    """
    Given a 1D signal, find the first and last index crossing a threshold
    calculated from the filtered signal data.
    """
    if len(signal) == 0:
        return None, None
        
    # Filter signal for threshold calculation (centered moving average)
    filtered_signal = np.convolve(signal, np.ones(window_size)/window_size, mode='same')
    
    # Calculate threshold using filtered signal
    p90 = np.percentile(filtered_signal, 99)
    p10 = np.percentile(filtered_signal, 1)
    th = (p90-p10) * threshold_ratio + p10
    
    # Find the first index crossing threshold
    start_idx_candidates = np.where(signal >= th)[0]
    if len(start_idx_candidates) == 0:
        return None, None
        
    return start_idx_candidates[0], start_idx_candidates[-1]

def get_video_segment(
    frame_metrics,
    cube,
    condition,
    line,
    data_dir="raw_data",
    threshold_ratio=0.3,
    metric_name='max_values',
    window_size=50
):
    """
    Load a single segmented video for specific cube/condition/line.
    """
    try:
        signal = frame_metrics[cube][condition][line][metric_name]
    except KeyError:
        print(f"Data not found for cube={cube}, condition={condition}, line={line}")
        return None, None, None
        
    # Find segmentation boundaries
    start_idx, end_idx = find_segmentation_range(
        signal, 
        threshold_ratio=threshold_ratio,
        window_size=window_size
    )
    
    if start_idx is None or end_idx is None:
        print(f"No frames above threshold for metric '{metric_name}'")
        return None, None, None

    # Construct the TIF path
    file_path = os.path.join(
        data_dir, 
        f"cube{cube}", 
        f"cube{cube}_C001H001S00{condition:02d}",
        f"cube{cube}_C001H001S00{condition:02d}-{(line-1):02d}.tif"
    )

    if not os.path.isfile(file_path):
        print(f"File not found: {file_path}")
        return None, None, None

    print(f"Loading frames {start_idx} to {end_idx} using metric '{metric_name}'")

    # Read frames one at a time to reduce memory usage
    frames_list = []
    with tifffile.TiffFile(file_path) as tif:
        total_frames = len(tif.pages)
        if end_idx >= total_frames:
            end_idx = total_frames - 1
        
        for i in range(start_idx, end_idx + 1):
            frame = tif.pages[i].asarray().astype(float)
            frames_list.append(frame)

    video_array = np.stack(frames_list, axis=0)
    return video_array, start_idx, end_idx

def iter_video_segments(
    frame_metrics,
    data_dir="raw_data",
    threshold_ratio=0.3,
    metric_name='max_values',
    window_size=50
):
    """
    Generator that yields one segmented video at a time.
    """
    for cube in frame_metrics:
        for condition in frame_metrics[cube]:
            for line in frame_metrics[cube][condition]:
                result = get_video_segment(
                    frame_metrics,
                    cube,
                    condition,
                    line,
                    data_dir=data_dir,
                    threshold_ratio=threshold_ratio,
                    metric_name=metric_name,
                    window_size=window_size
                )
                
                if result[0] is not None:
                    yield cube, condition, line, *result

def process_videos(frame_metrics, data_dir="raw_data", output_dir="segmented_videos_data"):
    """
    Process and save videos one at a time to minimize memory usage.
    """
    # Create output directory structure
    base_dir = Path(output_dir)
    if base_dir.exists():
        shutil.rmtree(base_dir)
    base_dir.mkdir(parents=True, exist_ok=True)
    
    # Initialize metadata dictionary
    metadata = {}
    
    # Count total videos to process
    total_videos = sum(
        1 for cube in frame_metrics 
        for condition in frame_metrics[cube] 
        for line in frame_metrics[cube][condition]
    )
    processed = 0
    
    try:
        # Process one video at a time
        for cube, condition, line, video_array, start_idx, end_idx in iter_video_segments(
            frame_metrics,
            data_dir=data_dir
        ):
            try:
                # Create directory structure for this video
                cube_dir = base_dir / f"cube_{cube}"
                cube_dir.mkdir(exist_ok=True)
                
                cond_dir = cube_dir / f"condition_{condition}"
                cond_dir.mkdir(exist_ok=True)
                
                # Initialize metadata structure if needed
                if cube not in metadata:
                    metadata[cube] = {}
                if condition not in metadata[cube]:
                    metadata[cube][condition] = {}
                
                # Save individual video file
                video_filename = cond_dir / f"line_{line}.pkl"
                with open(video_filename, "wb") as f:
                    pickle.dump(video_array, f)
                
                # Store file location in metadata
                metadata[cube][condition][line] = str(video_filename.relative_to(base_dir))
                
                # Free memory
                del video_array
                import gc
                gc.collect()
                
                processed += 1
                print(f"Processed: Cube {cube}, Condition {condition}, Line {line} [{processed}/{total_videos}]")
                
            except Exception as e:
                print(f"Error processing video (Cube {cube}, Condition {condition}, Line {line}): {str(e)}")
                continue
        
        # Save metadata file
        metadata_file = base_dir / "metadata.pkl"
        with open(metadata_file, "wb") as f:
            pickle.dump(metadata, f)
    
            
    except Exception as e:
        print(f"Error during processing: {str(e)}")
        if base_dir.exists():
            shutil.rmtree(base_dir)
        raise

# %%
# Process the videos
process_videos(
    results,
    data_dir="raw_data",
    output_dir="segmented_videos_data"
)
# Out:
# Loading frames 755 to 1029 using metric 'max_values'
# Processed: Cube 1, Condition 1, Line 1 [1/240]
# Loading frames 1073 to 1347 using metric 'max_values'
# Processed: Cube 1, Condition 1, Line 2 [2/240]
# Loading frames 1390 to 1664 using metric 'max_values'
# Processed: Cube 1, Condition 1, Line 3 [3/240]
# Loading frames 1708 to 1981 using metric 'max_values'
# Processed: Cube 1, Condition 1, Line 4 [4/240]
# Loading frames 2025 to 2299 using metric 'max_values'
# Processed: Cube 1, Condition 1, Line 5 [5/240]
# Loading frames 755 to 970 using metric 'max_values'
# Processed: Cube 1, Condition 2, Line 1 [6/240]
# Loading frames 956 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 2, Line 2 [7/240]
# Loading frames 1158 to 1373 using metric 'max_values'
# Processed: Cube 1, Condition 2, Line 3 [8/240]
# Loading frames 1359 to 1575 using metric 'max_values'
# Processed: Cube 1, Condition 2, Line 4 [9/240]
# Loading frames 1561 to 1776 using metric 'max_values'
# Processed: Cube 1, Condition 2, Line 5 [10/240]
# Loading frames 755 to 1132 using metric 'max_values'
# Processed: Cube 1, Condition 3, Line 1 [11/240]
# Loading frames 1279 to 1656 using metric 'max_values'
# Processed: Cube 1, Condition 3, Line 2 [12/240]
# Loading frames 1803 to 2180 using metric 'max_values'
# Processed: Cube 1, Condition 3, Line 3 [13/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 1, Condition 3, Line 4 [14/240]
# Loading frames 2851 to 3228 using metric 'max_values'
# Processed: Cube 1, Condition 3, Line 5 [15/240]
# Loading frames 756 to 1362 using metric 'max_values'
# Processed: Cube 1, Condition 4, Line 1 [16/240]
# Loading frames 1734 to 2337 using metric 'max_values'
# Processed: Cube 1, Condition 4, Line 2 [17/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 1, Condition 4, Line 3 [18/240]
# Loading frames 0 to 131 using metric 'max_values'
# Processed: Cube 1, Condition 4, Line 4 [19/240]
# Loading frames 433 to 1036 using metric 'max_values'
# Processed: Cube 1, Condition 4, Line 5 [20/240]
# Loading frames 755 to 1028 using metric 'max_values'
# Processed: Cube 1, Condition 5, Line 1 [21/240]
# Loading frames 1072 to 1346 using metric 'max_values'
# Processed: Cube 1, Condition 5, Line 2 [22/240]
# Loading frames 1390 to 1667 using metric 'max_values'
# Processed: Cube 1, Condition 5, Line 3 [23/240]
# Loading frames 1707 to 1981 using metric 'max_values'
# Processed: Cube 1, Condition 5, Line 4 [24/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 1, Condition 5, Line 5 [25/240]
# Loading frames 755 to 1132 using metric 'max_values'
# Processed: Cube 1, Condition 6, Line 1 [26/240]
# Loading frames 1280 to 1663 using metric 'max_values'
# Processed: Cube 1, Condition 6, Line 2 [27/240]
# Loading frames 1804 to 2183 using metric 'max_values'
# Processed: Cube 1, Condition 6, Line 3 [28/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 1, Condition 6, Line 4 [29/240]
# Loading frames 2852 to 3228 using metric 'max_values'
# Processed: Cube 1, Condition 6, Line 5 [30/240]
# Loading frames 755 to 1380 using metric 'max_values'
# Processed: Cube 1, Condition 7, Line 1 [31/240]
# Loading frames 1733 to 2342 using metric 'max_values'
# Processed: Cube 1, Condition 7, Line 2 [32/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 1, Condition 7, Line 3 [33/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 1, Condition 7, Line 4 [34/240]
# Loading frames 432 to 1037 using metric 'max_values'
# Processed: Cube 1, Condition 7, Line 5 [35/240]
# Loading frames 755 to 970 using metric 'max_values'
# Processed: Cube 1, Condition 8, Line 1 [36/240]
# Loading frames 956 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 8, Line 2 [37/240]
# Loading frames 1158 to 1373 using metric 'max_values'
# Processed: Cube 1, Condition 8, Line 3 [38/240]
# Loading frames 1359 to 1575 using metric 'max_values'
# Processed: Cube 1, Condition 8, Line 4 [39/240]
# Loading frames 1561 to 1776 using metric 'max_values'
# Processed: Cube 1, Condition 8, Line 5 [40/240]
# Loading frames 756 to 971 using metric 'max_values'
# Processed: Cube 1, Condition 9, Line 1 [41/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 9, Line 2 [42/240]
# Loading frames 1159 to 1374 using metric 'max_values'
# Processed: Cube 1, Condition 9, Line 3 [43/240]
# Loading frames 1360 to 1575 using metric 'max_values'
# Processed: Cube 1, Condition 9, Line 4 [44/240]
# Loading frames 1561 to 1777 using metric 'max_values'
# Processed: Cube 1, Condition 9, Line 5 [45/240]
# Loading frames 756 to 971 using metric 'max_values'
# Processed: Cube 1, Condition 10, Line 1 [46/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 10, Line 2 [47/240]
# Loading frames 1159 to 1374 using metric 'max_values'
# Processed: Cube 1, Condition 10, Line 3 [48/240]
# Loading frames 1360 to 1575 using metric 'max_values'
# Processed: Cube 1, Condition 10, Line 4 [49/240]
# Loading frames 1562 to 1777 using metric 'max_values'
# Processed: Cube 1, Condition 10, Line 5 [50/240]
# Loading frames 756 to 971 using metric 'max_values'
# Processed: Cube 1, Condition 11, Line 1 [51/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 11, Line 2 [52/240]
# Loading frames 1159 to 1374 using metric 'max_values'
# Processed: Cube 1, Condition 11, Line 3 [53/240]
# Loading frames 1360 to 1577 using metric 'max_values'
# Processed: Cube 1, Condition 11, Line 4 [54/240]
# Loading frames 1562 to 1777 using metric 'max_values'
# Processed: Cube 1, Condition 11, Line 5 [55/240]
# Loading frames 756 to 971 using metric 'max_values'
# Processed: Cube 1, Condition 12, Line 1 [56/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 1, Condition 12, Line 2 [57/240]
# Loading frames 1159 to 1374 using metric 'max_values'
# Processed: Cube 1, Condition 12, Line 3 [58/240]
# Loading frames 1360 to 1575 using metric 'max_values'
# Processed: Cube 1, Condition 12, Line 4 [59/240]
# Loading frames 1562 to 1777 using metric 'max_values'
# Processed: Cube 1, Condition 12, Line 5 [60/240]
# Loading frames 756 to 1360 using metric 'max_values'
# Processed: Cube 2, Condition 1, Line 1 [61/240]
# Loading frames 1733 to 2353 using metric 'max_values'
# Processed: Cube 2, Condition 1, Line 2 [62/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 2, Condition 1, Line 3 [63/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 2, Condition 1, Line 4 [64/240]
# Loading frames 433 to 1055 using metric 'max_values'
# Processed: Cube 2, Condition 1, Line 5 [65/240]
# Loading frames 755 to 970 using metric 'max_values'
# Processed: Cube 2, Condition 2, Line 1 [66/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 2, Condition 2, Line 2 [67/240]
# Loading frames 1158 to 1373 using metric 'max_values'
# Processed: Cube 2, Condition 2, Line 3 [68/240]
# Loading frames 1359 to 1575 using metric 'max_values'
# Processed: Cube 2, Condition 2, Line 4 [69/240]
# Loading frames 1561 to 1776 using metric 'max_values'
# Processed: Cube 2, Condition 2, Line 5 [70/240]
# Loading frames 756 to 1132 using metric 'max_values'
# Processed: Cube 2, Condition 3, Line 1 [71/240]
# Loading frames 1280 to 1656 using metric 'max_values'
# Processed: Cube 2, Condition 3, Line 2 [72/240]
# Loading frames 1803 to 2180 using metric 'max_values'
# Processed: Cube 2, Condition 3, Line 3 [73/240]
# Loading frames 2328 to 2704 using metric 'max_values'
# Processed: Cube 2, Condition 3, Line 4 [74/240]
# Loading frames 2852 to 3228 using metric 'max_values'
# Processed: Cube 2, Condition 3, Line 5 [75/240]
# Loading frames 757 to 1132 using metric 'max_values'
# Processed: Cube 2, Condition 4, Line 1 [76/240]
# Loading frames 1281 to 1694 using metric 'max_values'
# Processed: Cube 2, Condition 4, Line 2 [77/240]
# Loading frames 1805 to 2180 using metric 'max_values'
# Processed: Cube 2, Condition 4, Line 3 [78/240]
# Loading frames 2329 to 2716 using metric 'max_values'
# Processed: Cube 2, Condition 4, Line 4 [79/240]
# Loading frames 2854 to 3228 using metric 'max_values'
# Processed: Cube 2, Condition 4, Line 5 [80/240]
# Loading frames 755 to 971 using metric 'max_values'
# Processed: Cube 2, Condition 5, Line 1 [81/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 2, Condition 5, Line 2 [82/240]
# Loading frames 1158 to 1374 using metric 'max_values'
# Processed: Cube 2, Condition 5, Line 3 [83/240]
# Loading frames 1360 to 1575 using metric 'max_values'
# Processed: Cube 2, Condition 5, Line 4 [84/240]
# Loading frames 1561 to 1777 using metric 'max_values'
# Processed: Cube 2, Condition 5, Line 5 [85/240]
# Loading frames 755 to 1029 using metric 'max_values'
# Processed: Cube 2, Condition 6, Line 1 [86/240]
# Loading frames 1074 to 1346 using metric 'max_values'
# Processed: Cube 2, Condition 6, Line 2 [87/240]
# Loading frames 1390 to 1663 using metric 'max_values'
# Processed: Cube 2, Condition 6, Line 3 [88/240]
# Loading frames 1708 to 1981 using metric 'max_values'
# Processed: Cube 2, Condition 6, Line 4 [89/240]
# Loading frames 2025 to 2299 using metric 'max_values'
# Processed: Cube 2, Condition 6, Line 5 [90/240]
# Loading frames 762 to 1392 using metric 'max_values'
# Processed: Cube 2, Condition 7, Line 1 [91/240]
# Loading frames 1748 to 2368 using metric 'max_values'
# Processed: Cube 2, Condition 7, Line 2 [92/240]
# Loading frames 2716 to 3255 using metric 'max_values'
# Processed: Cube 2, Condition 7, Line 3 [93/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 2, Condition 7, Line 4 [94/240]
# Loading frames 438 to 1052 using metric 'max_values'
# Processed: Cube 2, Condition 7, Line 5 [95/240]
# Loading frames 755 to 1028 using metric 'max_values'
# Processed: Cube 2, Condition 8, Line 1 [96/240]
# Loading frames 1072 to 1346 using metric 'max_values'
# Processed: Cube 2, Condition 8, Line 2 [97/240]
# Loading frames 1390 to 1663 using metric 'max_values'
# Processed: Cube 2, Condition 8, Line 3 [98/240]
# Loading frames 1708 to 1981 using metric 'max_values'
# Processed: Cube 2, Condition 8, Line 4 [99/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 2, Condition 8, Line 5 [100/240]
# Loading frames 755 to 1133 using metric 'max_values'
# Processed: Cube 2, Condition 9, Line 1 [101/240]
# Loading frames 1279 to 1660 using metric 'max_values'
# Processed: Cube 2, Condition 9, Line 2 [102/240]
# Loading frames 1803 to 2189 using metric 'max_values'
# Processed: Cube 2, Condition 9, Line 3 [103/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 2, Condition 9, Line 4 [104/240]
# Loading frames 2852 to 3228 using metric 'max_values'
# Processed: Cube 2, Condition 9, Line 5 [105/240]
# Loading frames 755 to 971 using metric 'max_values'
# Processed: Cube 2, Condition 10, Line 1 [106/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 2, Condition 10, Line 2 [107/240]
# Loading frames 1158 to 1374 using metric 'max_values'
# Processed: Cube 2, Condition 10, Line 3 [108/240]
# Loading frames 1360 to 1575 using metric 'max_values'
# Processed: Cube 2, Condition 10, Line 4 [109/240]
# Loading frames 1561 to 1777 using metric 'max_values'
# Processed: Cube 2, Condition 10, Line 5 [110/240]
# Loading frames 755 to 1028 using metric 'max_values'
# Processed: Cube 2, Condition 11, Line 1 [111/240]
# Loading frames 1072 to 1346 using metric 'max_values'
# Processed: Cube 2, Condition 11, Line 2 [112/240]
# Loading frames 1390 to 1663 using metric 'max_values'
# Processed: Cube 2, Condition 11, Line 3 [113/240]
# Loading frames 1707 to 1981 using metric 'max_values'
# Processed: Cube 2, Condition 11, Line 4 [114/240]
# Loading frames 2024 to 2298 using metric 'max_values'
# Processed: Cube 2, Condition 11, Line 5 [115/240]
# Loading frames 756 to 1028 using metric 'max_values'
# Processed: Cube 2, Condition 12, Line 1 [116/240]
# Loading frames 1073 to 1346 using metric 'max_values'
# Processed: Cube 2, Condition 12, Line 2 [117/240]
# Loading frames 1391 to 1665 using metric 'max_values'
# Processed: Cube 2, Condition 12, Line 3 [118/240]
# Loading frames 1708 to 1981 using metric 'max_values'
# Processed: Cube 2, Condition 12, Line 4 [119/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 2, Condition 12, Line 5 [120/240]
# Loading frames 756 to 1380 using metric 'max_values'
# Processed: Cube 3, Condition 1, Line 1 [121/240]
# Loading frames 1733 to 2337 using metric 'max_values'
# Processed: Cube 3, Condition 1, Line 2 [122/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 3, Condition 1, Line 3 [123/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 3, Condition 1, Line 4 [124/240]
# Loading frames 432 to 1036 using metric 'max_values'
# Processed: Cube 3, Condition 1, Line 5 [125/240]
# Loading frames 756 to 1028 using metric 'max_values'
# Processed: Cube 3, Condition 2, Line 1 [126/240]
# Loading frames 1073 to 1345 using metric 'max_values'
# Processed: Cube 3, Condition 2, Line 2 [127/240]
# Loading frames 1391 to 1665 using metric 'max_values'
# Processed: Cube 3, Condition 2, Line 3 [128/240]
# Loading frames 1708 to 1979 using metric 'max_values'
# Processed: Cube 3, Condition 2, Line 4 [129/240]
# Loading frames 2026 to 2298 using metric 'max_values'
# Processed: Cube 3, Condition 2, Line 5 [130/240]
# Loading frames 756 to 1439 using metric 'max_values'
# Processed: Cube 3, Condition 3, Line 1 [131/240]
# Loading frames 1734 to 2337 using metric 'max_values'
# Processed: Cube 3, Condition 3, Line 2 [132/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 3, Condition 3, Line 3 [133/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 3, Condition 3, Line 4 [134/240]
# Loading frames 433 to 1054 using metric 'max_values'
# Processed: Cube 3, Condition 3, Line 5 [135/240]
# Loading frames 755 to 1359 using metric 'max_values'
# Processed: Cube 3, Condition 4, Line 1 [136/240]
# Loading frames 1733 to 2336 using metric 'max_values'
# Processed: Cube 3, Condition 4, Line 2 [137/240]
# Loading frames 2710 to 3255 using metric 'max_values'
# Processed: Cube 3, Condition 4, Line 3 [138/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 3, Condition 4, Line 4 [139/240]
# Loading frames 432 to 1036 using metric 'max_values'
# Processed: Cube 3, Condition 4, Line 5 [140/240]
# Loading frames 756 to 1133 using metric 'max_values'
# Processed: Cube 3, Condition 5, Line 1 [141/240]
# Loading frames 1280 to 1656 using metric 'max_values'
# Processed: Cube 3, Condition 5, Line 2 [142/240]
# Loading frames 1804 to 2181 using metric 'max_values'
# Processed: Cube 3, Condition 5, Line 3 [143/240]
# Loading frames 2328 to 2705 using metric 'max_values'
# Processed: Cube 3, Condition 5, Line 4 [144/240]
# Loading frames 2852 to 3228 using metric 'max_values'
# Processed: Cube 3, Condition 5, Line 5 [145/240]
# Loading frames 757 to 1134 using metric 'max_values'
# Processed: Cube 3, Condition 6, Line 1 [146/240]
# Loading frames 1282 to 1657 using metric 'max_values'
# Processed: Cube 3, Condition 6, Line 2 [147/240]
# Loading frames 1805 to 2181 using metric 'max_values'
# Processed: Cube 3, Condition 6, Line 3 [148/240]
# Loading frames 2329 to 2705 using metric 'max_values'
# Processed: Cube 3, Condition 6, Line 4 [149/240]
# Loading frames 2854 to 3229 using metric 'max_values'
# Processed: Cube 3, Condition 6, Line 5 [150/240]
# Loading frames 755 to 1132 using metric 'max_values'
# Processed: Cube 3, Condition 7, Line 1 [151/240]
# Loading frames 1280 to 1656 using metric 'max_values'
# Processed: Cube 3, Condition 7, Line 2 [152/240]
# Loading frames 1804 to 2180 using metric 'max_values'
# Processed: Cube 3, Condition 7, Line 3 [153/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 3, Condition 7, Line 4 [154/240]
# Loading frames 2852 to 3228 using metric 'max_values'
# Processed: Cube 3, Condition 7, Line 5 [155/240]
# Loading frames 756 to 973 using metric 'max_values'
# Processed: Cube 3, Condition 8, Line 1 [156/240]
# Loading frames 958 to 1172 using metric 'max_values'
# Processed: Cube 3, Condition 8, Line 2 [157/240]
# Loading frames 1159 to 1374 using metric 'max_values'
# Processed: Cube 3, Condition 8, Line 3 [158/240]
# Loading frames 1361 to 1575 using metric 'max_values'
# Processed: Cube 3, Condition 8, Line 4 [159/240]
# Loading frames 1562 to 1777 using metric 'max_values'
# Processed: Cube 3, Condition 8, Line 5 [160/240]
# Loading frames 756 to 1029 using metric 'max_values'
# Processed: Cube 3, Condition 9, Line 1 [161/240]
# Loading frames 1073 to 1347 using metric 'max_values'
# Processed: Cube 3, Condition 9, Line 2 [162/240]
# Loading frames 1390 to 1664 using metric 'max_values'
# Processed: Cube 3, Condition 9, Line 3 [163/240]
# Loading frames 1708 to 1989 using metric 'max_values'
# Processed: Cube 3, Condition 9, Line 4 [164/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 3, Condition 9, Line 5 [165/240]
# Loading frames 757 to 1359 using metric 'max_values'
# Processed: Cube 3, Condition 10, Line 1 [166/240]
# Loading frames 1735 to 2336 using metric 'max_values'
# Processed: Cube 3, Condition 10, Line 2 [167/240]
# Loading frames 2712 to 3255 using metric 'max_values'
# Processed: Cube 3, Condition 10, Line 3 [168/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 3, Condition 10, Line 4 [169/240]
# Loading frames 434 to 1056 using metric 'max_values'
# Processed: Cube 3, Condition 10, Line 5 [170/240]
# Loading frames 755 to 1132 using metric 'max_values'
# Processed: Cube 3, Condition 11, Line 1 [171/240]
# Loading frames 1279 to 1656 using metric 'max_values'
# Processed: Cube 3, Condition 11, Line 2 [172/240]
# Loading frames 1803 to 2180 using metric 'max_values'
# Processed: Cube 3, Condition 11, Line 3 [173/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 3, Condition 11, Line 4 [174/240]
# Loading frames 2851 to 3228 using metric 'max_values'
# Processed: Cube 3, Condition 11, Line 5 [175/240]
# Loading frames 756 to 1361 using metric 'max_values'
# Processed: Cube 3, Condition 12, Line 1 [176/240]
# Loading frames 1734 to 2337 using metric 'max_values'
# Processed: Cube 3, Condition 12, Line 2 [177/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 3, Condition 12, Line 3 [178/240]
# Loading frames 0 to 67 using metric 'max_values'
# Processed: Cube 3, Condition 12, Line 4 [179/240]
# Loading frames 433 to 1045 using metric 'max_values'
# Processed: Cube 3, Condition 12, Line 5 [180/240]
# Loading frames 755 to 1142 using metric 'max_values'
# Processed: Cube 4, Condition 1, Line 1 [181/240]
# Loading frames 1279 to 1661 using metric 'max_values'
# Processed: Cube 4, Condition 1, Line 2 [182/240]
# Loading frames 1803 to 2192 using metric 'max_values'
# Processed: Cube 4, Condition 1, Line 3 [183/240]
# Loading frames 2327 to 2704 using metric 'max_values'
# Processed: Cube 4, Condition 1, Line 4 [184/240]
# Loading frames 2851 to 3228 using metric 'max_values'
# Processed: Cube 4, Condition 1, Line 5 [185/240]
# Loading frames 755 to 971 using metric 'max_values'
# Processed: Cube 4, Condition 2, Line 1 [186/240]
# Loading frames 957 to 1172 using metric 'max_values'
# Processed: Cube 4, Condition 2, Line 2 [187/240]
# Loading frames 1158 to 1374 using metric 'max_values'
# Processed: Cube 4, Condition 2, Line 3 [188/240]
# Loading frames 1359 to 1575 using metric 'max_values'
# Processed: Cube 4, Condition 2, Line 4 [189/240]
# Loading frames 1561 to 1777 using metric 'max_values'
# Processed: Cube 4, Condition 2, Line 5 [190/240]
# Loading frames 757 to 1359 using metric 'max_values'
# Processed: Cube 4, Condition 3, Line 1 [191/240]
# Loading frames 1735 to 2389 using metric 'max_values'
# Processed: Cube 4, Condition 3, Line 2 [192/240]
# Loading frames 2712 to 3255 using metric 'max_values'
# Processed: Cube 4, Condition 3, Line 3 [193/240]
# Loading frames 0 to 76 using metric 'max_values'
# Processed: Cube 4, Condition 3, Line 4 [194/240]
# Loading frames 434 to 1035 using metric 'max_values'
# Processed: Cube 4, Condition 3, Line 5 [195/240]
# Loading frames 756 to 1366 using metric 'max_values'
# Processed: Cube 4, Condition 4, Line 1 [196/240]
# Loading frames 1733 to 2337 using metric 'max_values'
# Processed: Cube 4, Condition 4, Line 2 [197/240]
# Loading frames 2711 to 3255 using metric 'max_values'
# Processed: Cube 4, Condition 4, Line 3 [198/240]
# Loading frames 0 to 59 using metric 'max_values'
# Processed: Cube 4, Condition 4, Line 4 [199/240]
# Loading frames 433 to 1036 using metric 'max_values'
# Processed: Cube 4, Condition 4, Line 5 [200/240]
# Loading frames 756 to 1029 using metric 'max_values'
# Processed: Cube 4, Condition 5, Line 1 [201/240]
# Loading frames 1074 to 1347 using metric 'max_values'
# Processed: Cube 4, Condition 5, Line 2 [202/240]
# Loading frames 1392 to 1665 using metric 'max_values'
# Processed: Cube 4, Condition 5, Line 3 [203/240]
# Loading frames 1709 to 1985 using metric 'max_values'
# Processed: Cube 4, Condition 5, Line 4 [204/240]
# Loading frames 2026 to 2299 using metric 'max_values'
# Processed: Cube 4, Condition 5, Line 5 [205/240]
# Loading frames 758 to 1385 using metric 'max_values'
# Processed: Cube 4, Condition 6, Line 1 [206/240]
# Loading frames 1737 to 2359 using metric 'max_values'
# Processed: Cube 4, Condition 6, Line 2 [207/240]
# Loading frames 2714 to 3255 using metric 'max_values'
# Processed: Cube 4, Condition 6, Line 3 [208/240]
# Loading frames 0 to 102 using metric 'max_values'
# Processed: Cube 4, Condition 6, Line 4 [209/240]
# Loading frames 436 to 1086 using metric 'max_values'
# Processed: Cube 4, Condition 6, Line 5 [210/240]
# Loading frames 755 to 1028 using metric 'max_values'
# Processed: Cube 4, Condition 7, Line 1 [211/240]
# Loading frames 1072 to 1349 using metric 'max_values'
# Processed: Cube 4, Condition 7, Line 2 [212/240]
# Loading frames 1390 to 1663 using metric 'max_values'
# Processed: Cube 4, Condition 7, Line 3 [213/240]
# Loading frames 1707 to 1985 using metric 'max_values'
# Processed: Cube 4, Condition 7, Line 4 [214/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 4, Condition 7, Line 5 [215/240]
# Loading frames 755 to 1029 using metric 'max_values'
# Processed: Cube 4, Condition 8, Line 1 [216/240]
# Loading frames 1073 to 1346 using metric 'max_values'
# Processed: Cube 4, Condition 8, Line 2 [217/240]
# Loading frames 1390 to 1664 using metric 'max_values'
# Processed: Cube 4, Condition 8, Line 3 [218/240]
# Loading frames 1707 to 1981 using metric 'max_values'
# Processed: Cube 4, Condition 8, Line 4 [219/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 4, Condition 8, Line 5 [220/240]
# Loading frames 755 to 1029 using metric 'max_values'
# Processed: Cube 4, Condition 9, Line 1 [221/240]
# Loading frames 1072 to 1346 using metric 'max_values'
# Processed: Cube 4, Condition 9, Line 2 [222/240]
# Loading frames 1390 to 1664 using metric 'max_values'
# Processed: Cube 4, Condition 9, Line 3 [223/240]
# Loading frames 1707 to 1981 using metric 'max_values'
# Processed: Cube 4, Condition 9, Line 4 [224/240]
# Loading frames 2025 to 2298 using metric 'max_values'
# Processed: Cube 4, Condition 9, Line 5 [225/240]
# Loading frames 755 to 1131 using metric 'max_values'
# Processed: Cube 4, Condition 10, Line 1 [226/240]
# Loading frames 1280 to 1661 using metric 'max_values'
# Processed: Cube 4, Condition 10, Line 2 [227/240]
# Loading frames 1804 to 2180 using metric 'max_values'
# Processed: Cube 4, Condition 10, Line 3 [228/240]
# Loading frames 2328 to 2713 using metric 'max_values'
# Processed: Cube 4, Condition 10, Line 4 [229/240]
# Loading frames 2852 to 3230 using metric 'max_values'
# Processed: Cube 4, Condition 10, Line 5 [230/240]
# Loading frames 757 to 1140 using metric 'max_values'
# Processed: Cube 4, Condition 11, Line 1 [231/240]
# Loading frames 1281 to 1655 using metric 'max_values'
# Processed: Cube 4, Condition 11, Line 2 [232/240]
# Loading frames 1805 to 2239 using metric 'max_values'
# Processed: Cube 4, Condition 11, Line 3 [233/240]
# Loading frames 2330 to 2739 using metric 'max_values'
# Processed: Cube 4, Condition 11, Line 4 [234/240]
# Loading frames 2854 to 3254 using metric 'max_values'
# Processed: Cube 4, Condition 11, Line 5 [235/240]
# Loading frames 755 to 972 using metric 'max_values'
# Processed: Cube 4, Condition 12, Line 1 [236/240]
# Loading frames 956 to 1172 using metric 'max_values'
# Processed: Cube 4, Condition 12, Line 2 [237/240]
# Loading frames 1158 to 1373 using metric 'max_values'
# Processed: Cube 4, Condition 12, Line 3 [238/240]
# Loading frames 1359 to 1575 using metric 'max_values'
# Processed: Cube 4, Condition 12, Line 4 [239/240]
# Loading frames 1561 to 1776 using metric 'max_values'
# Processed: Cube 4, Condition 12, Line 5 [240/240]
